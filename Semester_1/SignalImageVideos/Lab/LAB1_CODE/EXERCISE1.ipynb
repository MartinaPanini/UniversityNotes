# %% [markdown]
# # Exercise 1: Analyzing Online Store Sales Data
#
# ## Objective:
# The goal of this exercise is to help students become familiar with NumPy, pandas, and Matplotlib by analyzing and visualizing sales and revenue data from an online store

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Create some sample data to work with. For example, you can generate random sales and revenue data for a hypothetical online store.
#
# TIP: use np.arange, np.random.randint and np.random.uniform
#
# see: https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html
# see: https://numpy.org/doc/stable/reference/generated/numpy.arange.html
# see: https://numpy.org/doc/stable/reference/random/generated/numpy.random.uniform.html

# %%
np.random.seed(100)
months = ['January','February','March',4,5,6,7,8,9,10,11,12]
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = np.random.randint(10000, 100000, 12)
revenue = np.random.randint(10000, 100000, 12)

# %% [markdown]
# Create a pandas DataFrame to store the data. You can also add column names for clarity.

# %%
data = {
    'Month': months, 
    'Sales': sales, 
    'Revenue': revenue
    }

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#         Month  Sales  Revenue
# 0     January  48408    81182
# 1    February  66088    59954
# 2       March  89683    88833
# 3       April  87655    96296
# 4         May  75615    69243
# 5        June  91840    27724
# 6        July  73370    17738
# 7      August  92270    52491
# 8   September  24260    48537
# 9     October  85618    90989
# 10   November  30533    16230
# 11   December  23890    94354

# %% [markdown]
# Calculate and display basic statistics for the data using pandas. For example, you can show the mean, median, and standard deviation of sales and revenue.
#
# TIPS: data['Sales'].mean()
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html

# %%
sales_mean = df['Sales'].mean()
revenue_median = df.Revenue.median()
sales_std = df.Sales.std()
print(f"Mean Sales: {sales_mean:.2f}")
print(f"Median Revenue: {revenue_median:.2f}")
print(f"Standard Deviation of Sales: {sales_std:.2f}")
# Out:
# Mean Sales: 65769.17
# Median Revenue: 64598.50
# Standard Deviation of Sales: 26970.54

# %% [markdown]
# Do the same using numpy

# %%
sales_mean_np = np.mean(sales)
revenue_median_np = np.median(revenue)
sales_std_np = np.std(sales)
print(f"Mean Sales (NumPy): {sales_mean_np:.2f}")
print(f"Median Revenue (NumPy): {revenue_median_np:.2f}")
print(f"Standard Deviation of Sales (NumPy): {sales_std_np:.2f}")
# Out:
# Mean Sales (NumPy): 65769.17
# Median Revenue (NumPy): 64598.50
# Standard Deviation of Sales (NumPy): 25822.32

# %% [markdown]
# Visualize the data using Matplotlib. Create a plot to show the monthly sales and a line plot for monthly revenue.

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.bar(df['Month'], df['Sales'], color='blue')
plt.title('Monthly Sales')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
plt.plot(df['Month'], df['Revenue'], marker='o', linestyle='-', color='green')
plt.title('Monthly Revenue')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
